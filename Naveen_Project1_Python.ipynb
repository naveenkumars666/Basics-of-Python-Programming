# %% [markdown]
# <a href="https://colab.research.google.com/github/naveenkumars666/Basics-of-Python-Programming/blob/main/Naveen_Project1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#10 function Calculator
#Authored by Naveen Kumar S
#Date:25-02-2023
#version 1.0



#print the available operations it can perform

print("1:ADDITION , 2:SUBSTRACTION, 3:MULTIPLICATION, 4:DIVISION, 5:MODULUS ")
print("6:LOG, 7:SQUARE ROOT, 8:SINE, 9:COS, 10:TAN ")



def double():
  a=float(input("Enter the first digit: "))
  b=float(input("Enter the second digit: "))

  # choice for addition
  if choice== 1:
    print("\nResult is: ", a.__add__(b))
  
  # choice for substraction
  elif choice== 2:
    print("\nResult is: ",a.__sub__(b))

            #Choice for multiplication
  elif choice == 3:
        print("\nResult is: ", a.__mul__(b))
           
            #Choice for division
  elif choice == 4 :
        #to avoid infinty division
        try:
          if b==0:
            raise ZeroDivisionError;
          #since we cannot divide any value by zero
        except ZeroDivisionError:
          print("Cannot divide by zero.")
        else:
            print("\nResult is: ", a.__div__(b))

            #Choice for double division
  
     #calculation for modulus function
  elif choice == 5:
    #cannot mod any number with zero since its undefined
        
        try:
          if b==0:
            raise ZeroDivisionError;
          #since we cannot divide any value by zero
        except ZeroDivisionError:
          print("Cannot divide by zero since it is undefined.")
           
        else:
             print("\nResult is: ",a%b)
    #logerathem function calculation
  elif choice == 6:
    #since log 0 is undifined
     if a==0:
       print("undefined")
       
     else:
      print(math.log(a,b))

def single():
  c = float(input("Enter first number: "))
  if choice == 7: 
   
   #there is no square root of negative number 
    if c < 0:
      print("\n Cannot take square root of a negative number.")
    else:
      print("\nResult:", math.sqrt(int(c)))
       #choices for sine
  elif choice == 8:
    print(round(math.sin(int(c))))
         #choise for cos 
  elif choice == 9:
    print(round(math.cos(int(c))))
  #choice for tan
  elif choice == 10:
    print(round(math.tan(int(c))))
  #2 variable operations 


  

choice = int(input("operation to perform "))

if choice <=0:
    print("invalid operation try again ")
elif choice <=6:
    double()
elif choice >=7:
  if choice >=11:
    print("invalid operation try again")
  else:
    single()

# %%
#10 function Calculator
#Authored by Naveen Kumar S
#Date:15-02-2023
#version 0.6

#import the required libraries
import math  

# Get the inputs for the operation
#allowed operations:"sqr","sin","cos","tan","add","sub","mul","div","mod","log","div2"
#it is case sensitive 
print("select a operation ::","sqr","sin","cos","tan","add","sub","mul","div","mod","log","div2")       

choice = str(input("operation to perform "))


a = float(input("Enter first number: "))
if choice == "sqr": 
   
   #there is no square root of negative number 
   if a < 0:
     print("\n Cannot take square root of a negative number.")
   else:
       print("\nResult:", math.sqrt(int(a)))
       #choices for sine
elif choice == "sin":
  print(round(math.sin(int(a))))
         #choise for cos 
elif choice == "cos":
  print(round(math.cos(int(a))))
  #choice for tan
elif choice == "tan":
  print(round(math.tan(int(a))))
  #2 variable operations 
else:
  b=float(input("input second number:"))
  if choice=="add":
     print("\nResult is: ", (a + b))
     
     #choice for substraction
  elif choice == "sub":
       print("\nResult is: ", (a - b))

            #Choice for multiplication
  elif choice =="mul":
        print("\nResult is: ", (a * b))
           
            #Choice for division
  elif choice =="div" :
        #to avoid infinty division
        if b == 0:
          #since we cannot divide any value by zero
          print("Cannot divide by zero.")
        else:
            print("\nResult is: ", (a / b))

            #Choice for double division
  elif choice == "div2":
       #if a dinominator is zero we cnt divid that
       if b == 0:
          print("\nCannot divide by zero.")
       else:
            print("\nResult is: ", (int(a // b)))
     #calculation for modulus function
  elif choice == "mod":
    #cannot mod any number with zero since its undefined
        
        if b==0:
             print("undefined")
           
        else:
             print("\nResult is: ", a % b)
    #logerathem function calculation
  elif choice == "log":
    #since log 0 is undifined
     if a==0:
       print("undefined")
       
     else:
      print(math.log(a,b))
 

  else:
    print("entered operation is not present")
    print("plese enter operations mentioned in the list:""sqr","sin","cos","tan","add","sub","mul","div","mod","log","div2")
# Out:
# select a operation :: sqr sin cos tan add sub mul div mod log div2
# operation to perform add
# Enter first number: 2
# input second number:3
#
# Result is:  5.0

# %%
#10 function Calculator
#Authored by Naveen Kumar S
#Date:25-02-2023
#version 0.7

#import the required libraries
import math

#print the available operations it can perform

print("1:ADDITION , 2:SUBSTRACTION, 3:MULTIPLICATION, 4:DIVISION, 5:MODULUS ")
print("6:LOG, 7:SQUARE ROOT, 8:SINE, 9:COS, 10:TAN ")



def double():
  a=float(input("Enter the first digit: "))
  b=float(input("Enter the second digit: "))

  # choice for addition
  if choice== 1:
    print("\nResult is: ", (a + b))
  
  # choice for substraction
  elif choice== 2:
    print("\nResult is: ", (a - b))

            #Choice for multiplication
  elif choice == 3:
        print("\nResult is: ", (a * b))
           
            #Choice for division
  elif choice == 4 :
        #to avoid infinty division
        if b == 0:
          #since we cannot divide any value by zero
          print("Cannot divide by zero.")
        else:
            print("\nResult is: ", (a / b))

            #Choice for double division
  
     #calculation for modulus function
  elif choice == 5:
    #cannot mod any number with zero since its undefined
        
        if b==0:
             print("undefined")
           
        else:
             print("\nResult is: ", a % b)
    #logerathem function calculation
  elif choice == 6:
    #since log 0 is undifined
     if a==0:
       print("undefined")
       
     else:
      print(math.log(a,b))

def single():
  c = float(input("Enter first number: "))
  if choice == 7: 
   
   #there is no square root of negative number 
    if c < 0:
      print("\n Cannot take square root of a negative number.")
    else:
      print("\nResult:", math.sqrt(int(c)))
       #choices for sine
  elif choice == 8:
    print(round(math.sin(int(c))))
         #choise for cos 
  elif choice == 9:
    print(round(math.cos(int(c))))
  #choice for tan
  elif choice == 10:
    print(round(math.tan(int(c))))
  #2 variable operations 


  

choice = int(input("operation to perform "))

if choice <=0:
    print("invalid operation try again ")
elif choice <=6:
  double()
elif choice >=7:
  if choice >=11:
    print("invalid operation try again")
  else:
    single()

# %%
#10 function Calculator
#Authored by Naveen Kumar S
#Date:25-02-2023
#version 0.8

#import the required libraries
import math

#print the available operations it can perform

print("1:ADDITION , 2:SUBSTRACTION, 3:MULTIPLICATION, 4:DIVISION, 5:MODULUS ")
print("6:LOG, 7:SQUARE ROOT, 8:SINE, 9:COS, 10:TAN ")



def double():
  a=float(input("Enter the first digit: "))
  b=float(input("Enter the second digit: "))

  # choice for addition
  if choice== 1:
    print("\nResult is: ", (a + b))
  
  # choice for substraction
  elif choice== 2:
    print("\nResult is: ", (a - b))

            #Choice for multiplication
  elif choice == 3:
        print("\nResult is: ", (a * b))
           
            #Choice for division
  elif choice == 4 :
        #to avoid infinty division
        try:
          if b==0:
            raise ZeroDivisionError;
          #since we cannot divide any value by zero
        except ZeroDivisionError:
          print("Cannot divide by zero.")
        else:
            print("\nResult is: ", (a / b))

            #Choice for double division
  
     #calculation for modulus function
  elif choice == 5:
    #cannot mod any number with zero since its undefined
        
        try:
          if b==0:
            raise ZeroDivisionError;
          #since we cannot divide any value by zero
        except ZeroDivisionError:
          print("Cannot divide by zero since it is undefined.")
           
        else:
             print("\nResult is: ", a % b)
    #logerathem function calculation
  elif choice == 6:
    #since log 0 is undifined
     if a==0:
       print("undefined")
       
     else:
      print(math.log(a,b))

def single():
  c = float(input("Enter first number: "))
  if choice == 7: 
   
   #there is no square root of negative number 
    if c < 0:
      print("\n Cannot take square root of a negative number.")
    else:
      print("\nResult:", math.sqrt(int(c)))
       #choices for sine
  elif choice == 8:
    print(round(math.sin(int(c))))
         #choise for cos 
  elif choice == 9:
    print(round(math.cos(int(c))))
  #choice for tan
  elif choice == 10:
    print(round(math.tan(int(c))))
  #2 variable operations 


  

choice = int(input("operation to perform "))

if choice <=0:
    print("invalid operation try again ")
elif choice <=6:
    double()
elif choice >=7:
  if choice >=11:
    print("invalid operation try again")
  else:
    single()
