# %% [markdown]
# <a href="https://colab.research.google.com/github/naveenkumars666/Basics-of-Python-Programming/blob/main/_NaveenKumar_project2_ATM_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ATM Machine Project-2
#Version 0.1
#Authored by Naveen Kumar S
#Date 18/02/2023
#Code is case sensetive
#Since Atm only uses numbers we only use numbers



#Define a function pin
print("WELCOME TO NOVA BANK ATM")
def pin():
  #P here holds all the pin numbers 
  p={1:1234,2:2345,3:3456,4:4567,5:5678,6:6789,7:7890,8:8900}
  #Enter your pin 
  b=int(input("enter your four digit pin"))
  #This statement checks if the pin is valid or not
  if b==p[cr]:
    print("Valid pin")
    #Goes to the bank function and continues the program
    bank()
  else:
    print("Invalid pin")
    am()

#Function used to display the end page
def am():
  print("Thank you for using NOVA BANK ATM")

#Function used to define bank details
def bank():
  #It shows the available balance
  print("Available balance is:",b[cr])
  #Input the amount to withdraw
  c=int(input("Enter the amount to withdraw:"))
  #Condetion used to deduct the amount 
  f=b[cr]-c
  if f>=0:
    print("Transaction succesful")
    print("Balance available after deduction",f)
    #This updates the balance
    b.update({cr:f})
    #use this print statement to see how the value gets updated in real time
    #print(b)
  else:
    print("Insufficiant funds")
    
#Condetion for printing the receipt
  print("Print receipt ")
  j=int(input("YES-1/NO-0:"))
  if j==1:
    print("Your current balance is:",f)
    am()
    con()
  else :
    print("Thank you for choosing to go green")
    con()
#Function to re start the transaction
def con():
  print("Do u wish to make another transaction")
  k=int(input("YES-1/NO-0:"))
  if k==1:
    pin()
  else:
    am()


#Here we enter the card numbers and check it 
cr=int(input("Enter your card number"))
#card is the card numbers 
card={1:12345,2:12546,3:34567,4:23245,5:78901,6:34556,7:23456,8:456567}
#b is the balance available in those cards 
b={1:1000,2:2000,3:3000,4:4000,5:3000,6:1000,7:5000,8:3000}

# If statement is true it goes to pin else shows invalid 
if cr in card:
  pin()
  
else:
  print("INVALID CARD")

# %% [markdown]
# “The ATM System is the project which is used to access their bank accounts in order to make cash withdrawals.
# Whenever the user needs to make cash withdraws, they can enter their PIN number (Personal Identification
# Number) and it will display the amount to be withdrawn in the form of 100's, 200’s, 500's and 2000’s.”
#
#
# Pseudo code
# *   Step1: Choose a card number
# *   Step2: Enter the pin
# *   Step3: Sent the value and check the value matches
# *   Step4: If the pin invalid re-enter the pin
# *   Step5: Ask the amount to be detected
# *   Step6: Check the amount is avaliable in the balance
# *   Step7: If it is there detect else insufficient balance
# *   Step8: Ask to print the receipt
# *   Step9: Ask to continue the transaction
# *   Step10: If yes repeat from the start

# %%
#ATM Machine Project-2
#Version 0.2
#Authored by Naveen Kumar S
#Date 18/02/2023
#Code is case sensetive
#Since Atm only uses numbers we only use numbers


#Define a function pin
print("WELCOME TO NOVA BANK ATM")
def pin():
  #P here holds all the pin numbers 
  p={1:1234,2:2345,3:3456,4:4567,5:5678,6:6789,7:7890,8:8900}
  #Enter your pin 
  b=int(input("Enter your four digit pin"))
  #This statement checks if the pin is valid or not
  if b==p[cr]:
    print("Valid pin")
    #Goes to the bank function and continues the program
    print("1:BALANCE")
    print("2:WITHDRAW")
    print("3:DEPOSITE")
    print("4:CANCEL")
    bal()
  else:
    print("Invalid pin")
    am()
#Function defined to know what operation to perform
def bal():
  ch=int(input("Enter your choice"))
  if ch==1:
    balance()
  elif ch==2:
    bank()
  elif ch==3:
    deposite()
  elif ch==4:
    am()
  else:
    print("Enter a valid choice")
    bal()

#Function to find the balance
def balance():
  print("Your available balance is:",b[cr])
  am()
  con()

#Functiom to deposite monwy
def deposite():
  gh=int(input("Enter the amount you want to deposite"))
  v=gh+b[cr]
  print("Your update balance after depossite is:",v)
  b.update({cr:v})
  am()
  con()


#Function used to display the end page
def am():
  print("Thank you for using NOVA BANK ATM")

#Function used to define  withdraw sequemce
def bank():
  #It shows the available balance
  print("Available balance is:",b[cr])
  #Input the amount to withdraw
  c=int(input("Enter the amount to withdraw:"))
  #Condetion used to deduct the amount 
  f=b[cr]-c
  if f>=0:
    print("Transaction succesful")
    print("Balance available after deduction",f)
    #This updates the balance
    b.update({cr:f})
    #use this print statement to see how the value gets updated in real time
    #print(b)
  else:
    print("Insufficiant funds")
    
#Condetion for printing the receipt
  print("Print receipt ")
  j=int(input("YES-1/NO-0:"))
  if j==1:
    print("Your current balance is:",f)
    am()
    con()
  else :
    print("Thank you for choosing to go green")
    con()
#Function to re start the transaction
def con():
  print("Do u wish to make another transaction")
  k=int(input("YES-1/NO-0:"))
  if k==1:
    pin()
  else:
    am()


#Here we enter the card numbers and check it 
cr=int(input("Enter your card number"))
#card is the card numbers 
card={1:12345,2:12546,3:34567,4:23245,5:78901,6:34556,7:23456,8:45656}
#b is the balance available in those cards 
b={1:1000,2:2000,3:3000,4:4000,5:3000,6:1000,7:5000,8:3000}

# If statement is true it goes to pin else shows invalid 
if cr in card:
  pin()
  
else:
  print("INVALID CARD")

# %% [markdown]
# Pseudo code
# *   Step1: Choose a card number
# *   Step2: Enter the pin
# *   Step3: Sent the value and check the value matches
# *   Step4: Check for pin validity
# *   Step5: Choose the operation to perform
# *   Step6: U can deposite ,check balance ,withdraw ,cancel the transactions
# *   Step7: Perform the operation u want
# *   Step8: Ask to print the receipt
# *   Step9: Ask to continue the transaction
# *   Step10: If yes repeat from the start
